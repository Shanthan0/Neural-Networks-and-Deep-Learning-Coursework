# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanthan0/Neural-Networks-and-Deep-Learning-Coursework/blob/main/ICP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path_to_csv = '/content/diabetes.csv'

# %%
import keras
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv(path_to_csv, header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.3324 - loss: 32.5471
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.3300 - loss: 22.0635
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.3592 - loss: 11.4970
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5183 - loss: 2.9857
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.6669 - loss: 1.9432
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.6149 - loss: 1.7207
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5895 - loss: 1.7165
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5994 - loss: 1.5097
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6087 - loss: 1.3536
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6308 - loss: 1.2372
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6251 - loss: 1.2502
# Epoch 12/100
# ...

# %% [markdown]
# Add more Dense layers to the existing code and check how the accuracy changes.

# %%
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Activation

# Load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv(path_to_csv, header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
d={}
# Experiment with different numbers of Dense layers
for num_layers in range(1, 4):  # Try 1, 2, and 3 hidden layers
  my_first_nn = Sequential()
  my_first_nn.add(Dense(20, input_dim=8, activation='relu'))  # First hidden layer

  # Add additional hidden layers based on the loop iteration
  for _ in range(num_layers - 1):
    my_first_nn.add(Dense(16, activation='relu'))  # Example hidden layer with 16 units and ReLU activation

  my_first_nn.add(Dense(1, activation='sigmoid'))  # Output layer
  my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

  # Train the model
  my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

  # Evaluate the model and print accuracy
  loss, accuracy = my_first_nn.evaluate(X_test, Y_test)
  d[num_layers]=accuracy

for num_layers, accuracy in d.items():
  print(f"Model with {num_layers} hidden layers: Accuracy - {accuracy:.4f}")
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - acc: 0.6807 - loss: 11.8362
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.6224 - loss: 5.4668
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.4658 - loss: 3.0968
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6053 - loss: 1.8995
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5805 - loss: 1.7257
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5753 - loss: 1.5906
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5884 - loss: 1.4721
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.6162 - loss: 1.2808
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6049 - loss: 1.4081
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6243 - loss: 1.1785
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6260 - loss: 1.2097
# Epoch 12/100
# ...

# %% [markdown]
# Change the data source to Breast Cancer dataset * available in the source code folder and make required
# changes. Report accuracy of the model.

# %%
path_to_csv = '/content/breastcancer.csv'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')

# Load the Breast Cancer dataset (replace 'breast_cancer_data.csv' with your actual file path)
df = pd.read_csv(path_to_csv)

df.drop(columns=['id'],inplace=True)
x=df.drop('diagnosis',axis=1)
y=df['diagnosis']

encoder = LabelEncoder()
y = encoder.fit_transform(y)

x_train, x_, y_train, y_ = train_test_split(x, y, test_size=0.20, random_state=42)
x_valid, x_test, y_valid, y_test = train_test_split(x_, y_, test_size=0.5, random_state=42)

model = Sequential([
    Dense(32, activation='relu', input_dim=30),

    Dense(16, activation='relu'),

    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])


model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid))
print(model.summary())
model.evaluate(x_test,y_test)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3628 - loss: 58.8043 - val_accuracy: 0.4737 - val_loss: 26.2086
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3465 - loss: 28.2299 - val_accuracy: 0.4737 - val_loss: 9.4590
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4073 - loss: 7.5631 - val_accuracy: 0.8421 - val_loss: 0.6828
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7689 - loss: 1.3945 - val_accuracy: 0.9123 - val_loss: 0.1932
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8176 - loss: 0.4481 - val_accuracy: 0.9474 - val_loss: 0.1360
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8990 - loss: 0.2607 - val_accuracy: 0.9123 - val_loss: 0.2163
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9267 - loss: 0.2138 - val_accuracy: 0.9298 - val_loss: 0.1263
# Epoch 8/100
# ...

# %% [markdown]
# Normalize the data before feeding the data to the model and check how the normalization change your
# accuracy

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')

# Load the Breast Cancer dataset (replace 'breast_cancer_data.csv' with your actual file path)
df = pd.read_csv(path_to_csv)

df.drop(columns=['id','Unnamed: 32'],inplace=True)
x=df.drop('diagnosis',axis=1)
y=df['diagnosis']

encoder = LabelEncoder()
y = encoder.fit_transform(y)

scaler = StandardScaler()
x = scaler.fit_transform(x)

x_train, x_, y_train, y_ = train_test_split(x, y, test_size=0.20, random_state=42)
x_valid, x_test, y_valid, y_test = train_test_split(x_, y_, test_size=0.5, random_state=42)

model = Sequential([
    Dense(32, activation='relu', input_dim=30),

    Dense(16, activation='relu'),

    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])


model.fit(x_train, y_train, epochs=100, validation_data=(x_valid, y_valid))
print(model.summary())
model.evaluate(x_test,y_test)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6830 - loss: 0.6537 - val_accuracy: 0.7193 - val_loss: 0.5198
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8243 - loss: 0.4097 - val_accuracy: 0.8596 - val_loss: 0.3602
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9257 - loss: 0.2877 - val_accuracy: 0.9123 - val_loss: 0.2744
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.2431 - val_accuracy: 0.9298 - val_loss: 0.2192
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9468 - loss: 0.1877 - val_accuracy: 0.9474 - val_loss: 0.1802
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9566 - loss: 0.1520 - val_accuracy: 0.9649 - val_loss: 0.1519
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9681 - loss: 0.1293 - val_accuracy: 0.9649 - val_loss: 0.1333
# Epoch 8/100
# ...

# %% [markdown]
# Plot the loss and accuracy for both training data and validation data using the history object in the source
# code.

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.8339 - loss: 0.5287 - val_accuracy: 0.9507 - val_loss: 0.1592
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9671 - loss: 0.1079 - val_accuracy: 0.9698 - val_loss: 0.0944
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9804 - loss: 0.0634 - val_accuracy: 0.9745 - val_loss: 0.0753
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9860 - loss: 0.0442 - val_accuracy: 0.9747 - val_loss: 0.0827
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9909 - loss: 0.0298 - val_accuracy: 0.9764 - val_loss: 0.0796
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9941 - loss: 0.0208 - val_accuracy: 0.9760 - val_loss: 0.0833
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9947 - loss: 0.0171 - val_accuracy: 0.9799 - val_loss: 0.0747
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select an image from the test data (e.g., the first image)
image_index = 0  # You can change this to any index
test_image = test_images[image_index]

# Plot the test image
plt.imshow(test_image, cmap='gray')
plt.title(f"Original Label: {test_labels[image_index]}")
plt.show()

# Preprocess the selected image for model prediction
# Reshape the image from (28, 28) to (1, 784)
test_image_reshaped = test_image.reshape(1, 784).astype('float')
test_image_reshaped /= 255.0  # Scale the values between 0 and 1

# Run inference on the reshaped image
prediction = model.predict(test_image_reshaped)

# Display the predicted label
predicted_label = np.argmax(prediction)
print(f"Model Prediction: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model Prediction: 7

# %% [markdown]
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.

# %%
# Create a new Sequential model
model_tanh = Sequential()

# Add two hidden layers with tanh activation function
model_tanh.add(Dense(512, activation='tanh', input_shape=(dimData,)))
model_tanh.add(Dense(512, activation='tanh'))
model_sigmoid.add(Dense(256, activation='sigmoid'))
# Output layer (softmax remains the same for multi-class classification)
model_tanh.add(Dense(10, activation='softmax'))

# Compile the model
model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history_tanh = model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                              validation_data=(test_data, test_labels_one_hot))

# Evaluate the model with tanh activation
test_loss_tanh, test_accuracy_tanh = model_tanh.evaluate(test_data, test_labels_one_hot)
print(f'Tanh Model Test Loss: {test_loss_tanh}, Test Accuracy: {test_accuracy_tanh}')
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.8271 - loss: 0.5578 - val_accuracy: 0.9049 - val_loss: 0.3115
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9367 - loss: 0.2046 - val_accuracy: 0.9539 - val_loss: 0.1523
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9652 - loss: 0.1161 - val_accuracy: 0.9487 - val_loss: 0.1585
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9744 - loss: 0.0861 - val_accuracy: 0.9641 - val_loss: 0.1106
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9816 - loss: 0.0610 - val_accuracy: 0.9762 - val_loss: 0.0752
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9862 - loss: 0.0456 - val_accuracy: 0.9751 - val_loss: 0.0717
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9905 - loss: 0.0331 - val_accuracy: 0.9767 - val_loss: 0.0712
# Epoch 8/10
# ...

# %% [markdown]
# Run the same code without scaling the images and check the performance?

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Print the shape of the images to confirm the dimensions
print(train_images.shape[1:])

# Process the data without scaling
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data = test_images.reshape(test_images.shape[0], dimData)

# Convert data to float but do NOT scale it between 0 and 1 (no division by 255)
train_data = train_data.astype('float')
test_data = test_data.astype('float')

# One-hot encode the labels
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Create the neural network model
model_no_scaling = Sequential()
model_no_scaling.add(Dense(512, activation='relu', input_shape=(dimData,)))
model_no_scaling.add(Dense(512, activation='relu'))
model_no_scaling.add(Dense(10, activation='softmax'))

# Compile the model
model_no_scaling.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model without scaling the images
history_no_scaling = model_no_scaling.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                                          validation_data=(test_data, test_labels_one_hot))

# Evaluate the model on the test data without scaling
test_loss_no_scaling, test_accuracy_no_scaling = model_no_scaling.evaluate(test_data, test_labels_one_hot)
print(f'Model without Scaling - Test Loss: {test_loss_no_scaling}, Test Accuracy: {test_accuracy_no_scaling}')

# Plot the training and validation loss
plt.plot(history_no_scaling.history['loss'], label='Training Loss (No Scaling)')
plt.plot(history_no_scaling.history['val_loss'], label='Validation Loss (No Scaling)')
plt.title('Loss over Epochs (No Scaling)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.plot(history_no_scaling.history['accuracy'], label='Training Accuracy (No Scaling)')
plt.plot(history_no_scaling.history['val_accuracy'], label='Validation Accuracy (No Scaling)')
plt.title('Accuracy over Epochs (No Scaling)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.8061 - loss: 19.3361 - val_accuracy: 0.8623 - val_loss: 1.5491
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.9451 - loss: 0.4645 - val_accuracy: 0.9364 - val_loss: 0.4997
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9592 - loss: 0.2733 - val_accuracy: 0.9586 - val_loss: 0.3378
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.9688 - loss: 0.1915 - val_accuracy: 0.9551 - val_loss: 0.3163
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9714 - loss: 0.1634 - val_accuracy: 0.9579 - val_loss: 0.3121
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.9758 - loss: 0.1489 - val_accuracy: 0.9516 - val_loss: 0.4369
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9771 - loss: 0.1447 - val_accuracy: 0.9697 - val_loss: 0.3279
# Epoch 8/10
# ...
